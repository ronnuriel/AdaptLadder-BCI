# %% [markdown]
# # T15 Data Sanity
#
# Generates `results/tables/t15_dataset_summary.csv`.

# %%
# %load_ext autoreload
# %autoreload 2
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from src.drift_metrics import summarize_t15_dataset

summary = summarize_t15_dataset(ROOT / 'data/raw/hdf5_data_final')
out = ROOT / 'results/tables/t15_dataset_summary.csv'
out.parent.mkdir(parents=True, exist_ok=True)
summary.to_csv(out, index=False)
summary.head()
