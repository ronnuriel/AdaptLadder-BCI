# %% [markdown]
# # T15 Lightweight Adaptation
#
# Planned comparison: no adaptation, target z-score, source-to-target moment matching, diagonal affine correction. The next implementation step is attaching these transforms to decoder-facing metrics.

# %%
from src.adaptation import target_zscore, source_to_target_moment_match, diagonal_affine
# TODO: run decoder before/after adaptation and save results/tables/t15_adaptation_summary.csv
